# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Data Loading

# %%
data = pd.read_csv('C:/Users/Martin/Desktop/Codage/Jeux de données/WineQuality/data/winequality-red.csv')

# %%
data.shape
# Out:
# (1599, 12)

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Il n'y a pas de valeur nulle dans le dataset

# %% [markdown]
# # Data analysis

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
data.nunique()
# Out:
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %% [markdown]
# ## Correlations

# %% [markdown]
# ### Finding correlations

# %%
plt.subplots(figsize=(20,12))
sns.heatmap(data.corr(),annot = True,cmap = 'viridis')
# Out:
# <Axes: >

# %%
corr = data.corr()

for i in range(len(corr)):
    
    a = ((corr.iloc[i]>0.5) & (corr.iloc[i]!=1))
    b = ((corr.iloc[i]<(-0.5)) & (corr.iloc[i]!=1))
    axes = a.axes[0]
    
    print('Correlations according to', a.name, ':\n')
    
    print('Positive :')
    if True in a.values:
        for i in range (len(axes)):
            if a[axes[i]]== True:
                print('    - ' + axes[i])
    else:
        print('    - None')
    print('Negative :')
    if True in b.values:
        for i in range (len(axes)):
            if b[axes[i]]== True:
                print('    - ' + axes[i])
    else:
        print('    - None')
        
    print('\n')
# Out:
# Correlations according to fixed acidity :
#
# Positive :
#     - citric acid
#     - density
# Negative :
#     - pH
#
#
# Correlations according to volatile acidity :
#
# Positive :
#     - None
# Negative :
#     - citric acid
#
#
# Correlations according to citric acid :
#
# Positive :
#     - fixed acidity
# Negative :
#     - volatile acidity
#     - pH
#
#
# Correlations according to residual sugar :
#
# Positive :
#     - None
# Negative :
#     - None
#
#
# Correlations according to chlorides :
#
# Positive :
#     - None
# Negative :
#     - None
#
#
# Correlations according to free sulfur dioxide :
#
# Positive :
#     - total sulfur dioxide
# Negative :
#     - None
#
#
# Correlations according to total sulfur dioxide :
#
# Positive :
#     - free sulfur dioxide
# Negative :
#     - None
#
#
# Correlations according to density :
#
# Positive :
#     - fixed acidity
# Negative :
#     - None
#
#
# Correlations according to pH :
#
# Positive :
#     - None
# Negative :
# ...

# %% [markdown]
# ### Plotting charts with previous correlations

# %% [markdown]
# #### According to fixed acidity

# %%
#data["pH"].describe()

# %%
#pH_hue = data["pH"]

#for i in range (len(pH_hue)):
#    if pH_hue[i] < 2.875:
#        pH_hue[i] = 2.75
#    elif pH_hue[i] < 3.125:
#        pH_hue[i] = 3
#    elif pH_hue[i] < 3.375:
#        pH_hue[i] = 3.25
#    elif pH_hue[i] < 3.625:
#        pH_hue[i] = 3.5
#    elif pH_hue[i] < 3.875:
#        pH_hue[i] = 3.75
#    else:
#        pH_hue[i] = 4

sns.relplot(x='fixed acidity', y="citric acid", hue="pH", data=data, height=10)#, palette=sns.color_palette('rocket', n_colors=5))
plt.show()

#cmap = sns.color_palette('rocket', n_colors=5)
#flights = data.drop(columns=["volatile acidity", "residual sugar", "chlorides", "free sulfur dioxide", "total sulfur dioxide", "density", "sulphates", "alcohol", "quality"])
#flights = flights.pivot_table("pH", "fixed acidity", "citric acid")
#ax = sns.heatmap(flights, cmap = cmap)

# %%
sns.relplot(x='fixed acidity', y="density", data=data, hue="quality", height=20)
plt.show()

# %%
sns.relplot(x='fixed acidity', y="pH", hue="quality", data=data, height=15)
plt.show()

# %% [markdown]
# #### According to volatile acidity

# %%
sns.relplot(x='volatile acidity', y="citric acid", hue="quality", data=data, height=20)
plt.show()

# %% [markdown]
# #### According to citric acid

# %%
sns.relplot(x='citric acid', y="pH", hue="quality", data=data, height=15)
plt.show()

# %% [markdown]
# #### According to free sulfur dioxide

# %%
sns.relplot(x='free sulfur dioxide', y="total sulfur dioxide", hue="quality", data=data, height=15)
plt.show()

# %% [markdown]
# ## Plotting histograms

# %%
fig, ax1 = plt.subplots(3,4, figsize=(24,30))
k = 0
columns = list(data.columns)
for i in range(3):
    for j in range(4):
            sns.histplot(x=data[columns[k]], ax = ax1[i][j], color = 'red')
            k += 1
plt.show()

# %%
quality_corr1 = data.corr()['quality'].sort_values()
quality_corr1
# Out:
# volatile acidity       -0.390558
# total sulfur dioxide   -0.185100
# density                -0.174919
# chlorides              -0.128907
# pH                     -0.057731
# free sulfur dioxide    -0.050656
# residual sugar          0.013732
# fixed acidity           0.124052
# citric acid             0.226373
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %% [markdown]
# We can see that 'residual sugar' ; 'chlorides' ; 'free sulfur dioxide' ; 'total sulfur dioxide' ; 'sulphates' histograms are mostly on the left of 'x' axis.

# %%
def log_transform(col):
    return np.log(col[0])

data['residual sugar'] = data[['residual sugar']].apply(log_transform, axis=1)
data['chlorides'] = data[['chlorides']].apply(log_transform, axis=1)
data['free sulfur dioxide'] = data[['free sulfur dioxide']].apply(log_transform, axis=1)
data['total sulfur dioxide'] = data[['total sulfur dioxide']].apply(log_transform, axis=1)
data['sulphates'] = data[['sulphates']].apply(log_transform, axis=1)

# %%
color = sns.color_palette("pastel")

fig, ax1 = plt.subplots(3,4, figsize=(24,30))
k = 0
columns = list(data.columns)
for i in range(3):
    for j in range(4):
            sns.histplot(data[columns[k]], ax = ax1[i][j], color = 'green')
            k += 1
plt.show()

# %%
quality_corr2 = data.corr()['quality'].sort_values()
quality_corr2
# Out:
# volatile acidity       -0.390558
# chlorides              -0.176140
# density                -0.174919
# total sulfur dioxide   -0.170143
# pH                     -0.057731
# free sulfur dioxide    -0.050087
# residual sugar          0.023533
# fixed acidity           0.124052
# citric acid             0.226373
# sulphates               0.308642
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %%
for i in range(len(quality_corr1)):
    if quality_corr1[i] == quality_corr2[i]:
        print(quality_corr1.to_string().split('\n')[i].split('  ')[0] + ' : pas de changement')
    else:
        print(quality_corr1.to_string().split('\n')[i].split('  ')[0] + ' :')
        print('    - Avant : ' + str(quality_corr1[i]))
        print('    - Après : ' + str(quality_corr2[i]))
    print()
# Out:
# volatile acidity : pas de changement
#
# total sulfur dioxide :
#     - Avant : -0.1851002889265377
#     - Après : -0.1761399649602995
#
# density : pas de changement
#
# chlorides :
#     - Avant : -0.12890655993005296
#     - Après : -0.1701427191892691
#
# pH : pas de changement
#
# free sulfur dioxide :
#     - Avant : -0.05065605724427594
#     - Après : -0.05008749424037654
#
# residual sugar :
#     - Avant : 0.013731637340065779
#     - Après : 0.023533306758789813
#
# fixed acidity : pas de changement
#
# citric acid : pas de changement
#
# sulphates :
#     - Avant : 0.25139707906925995
#     - Après : 0.30864193232101056
#
# alcohol : pas de changement
#
# quality : pas de changement

# %% [markdown]
# On remarque que les courbes 'sulphates' ; 'residual sugar' ; 'chlorides' ont vus leur corrélation avec la qualité du vin augmenter.
